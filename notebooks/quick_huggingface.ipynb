# %%
from datasets import load_dataset

# %%
# EVA transcription
ds = load_dataset("Ched-ai/voynich-eva")
print(f"Lines: {len(ds['train'])}")  # 4,072
# Out:
# README.md:   0%|          | 0.00/8.57k [00:00<?, ?B/s]
# eva_lines.parquet: reconstructing file:   0%|          |  0.00B /  302kB
# eva_lines.parquet: downloading bytes:           |  0.00B
# Generating train split:   0%|          | 0/4072 [00:00<?, ? examples/s]
# Lines: 4072

# %%
# Metadata
pages = load_dataset("Ched-ai/voynich-manuscript-metadata", "pages")
folios = load_dataset("Ched-ai/voynich-manuscript-metadata", "folios")
quires = load_dataset("Ched-ai/voynich-manuscript-metadata", "quires")
# Out:
# README.md:   0%|          | 0.00/6.94k [00:00<?, ?B/s]
# pages.parquet: reconstructing file:   0%|          |  0.00B / 9.79kB
# pages.parquet: downloading bytes:           |  0.00B
# Generating train split:   0%|          | 0/226 [00:00<?, ? examples/s]
# folios.parquet: reconstructing file:   0%|          |  0.00B / 7.05kB
# folios.parquet: downloading bytes:           |  0.00B
# Generating train split:   0%|          | 0/102 [00:00<?, ? examples/s]
# quires.parquet: reconstructing file:   0%|          |  0.00B / 3.77kB
# quires.parquet: downloading bytes:           |  0.00B
# Generating train split:   0%|          | 0/18 [00:00<?, ? examples/s]

# %%
# Cross-transcription comparison
mismatch = load_dataset("Ched-ai/voynich-transcription-mismatch")
# Out:
# README.md:   0%|          | 0.00/8.55k [00:00<?, ?B/s]
# mismatch_index.parquet: reconstructing file:   0%|          |  0.00B /  599kB
# mismatch_index.parquet: downloading bytes:           |  0.00B
# Generating train split:   0%|          | 0/4072 [00:00<?, ? examples/s]

# %%
pages
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['page_id', 'folio_id', 'side', 'folio_number', 'quire_id', 'quire_letter', 'page_in_quire', 'currier_language', 'hand', 'illustration_type', 'line_count', 'label_count', 'has_text', 'is_foldout_panel', 'panel_number', 'total_panels', 'is_missing', 'notes', 'section_value', 'section_attribution', 'section_confidence', 'section_disputed'],
#         num_rows: 226
#     })
# })

# %%
folios
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['folio_id', 'folio_number', 'quire_id', 'recto_page_id', 'verso_page_ids', 'is_foldout', 'panel_count', 'is_missing', 'total_lines', 'currier_language', 'notes', 'section_value', 'section_attribution', 'section_confidence', 'section_disputed'],
#         num_rows: 102
#     })
# })

# %%
quires
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['quire_id', 'quire_letter', 'folio_ids', 'folio_count', 'page_count', 'is_complete', 'total_lines', 'sections', 'notes'],
#         num_rows: 18
#     })
# })

# %%
mismatch
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['page_id', 'line_number', 'line_id', 'zl_text', 'it_text', 'cd_text', 'fg_text', 'gc_text', 'status', 'eva_agreement', 'similarity_score', 'sources_present', 'sources_missing', 'notes'],
#         num_rows: 4072
#     })
# })

# %%
pages['train'][0]
# Out:
# {'page_id': 'f1r',
#  'folio_id': 'f1',
#  'side': 'recto',
#  'folio_number': 1,
#  'quire_id': 'qA',
#  'quire_letter': 'A',
#  'page_in_quire': 'A',
#  'currier_language': 'A',
#  'hand': '1',
#  'illustration_type': 'T',
#  'line_count': 24,
#  'label_count': 0,
#  'has_text': True,
#  'is_foldout_panel': False,
#  'panel_number': None,
#  'total_panels': None,
#  'is_missing': False,
#  'notes': [],
#  'section_value': 'herbal_a',
#  'section_attribution': 'zandbergen_voynich_nu',
#  'section_confidence': 'medium',
#  'section_disputed': True}
