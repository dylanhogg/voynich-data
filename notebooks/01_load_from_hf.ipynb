# %% [markdown]
# # VCAT: Load and Explore Voynich EVA Data
#
# This notebook demonstrates how to load the Voynich EVA transcription dataset from Hugging Face.

# %%
# Install datasets library if needed
# !pip install datasets

# %%
import pandas as pd
from datasets import load_dataset

# Load from Hugging Face
ds = load_dataset("Ched-ai/voynich-eva", "default")
print(ds)
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['page_id', 'line_number', 'line_index', 'line_id', 'text', 'text_clean', 'line_type', 'position', 'quire', 'section', 'currier_language', 'hand', 'illustration_type', 'char_count', 'word_count', 'has_uncertain', 'has_illegible', 'has_alternatives', 'has_high_ascii', 'source', 'source_version'],
#         num_rows: 4072
#     })
# })

# %%
# View first record
print(ds["train"][0])
# Out:
# {'page_id': 'f1r', 'line_number': 1, 'line_index': 1, 'line_id': 'f1r:1', 'text': '<%>fachys.ykal.ar.ataiin.shol.shory.[cth:oto]res.y.kor.sholdy<!@254;>', 'text_clean': 'fachys.ykal.ar.ataiin.shol.shory.cthres.y.kor.sholdy', 'line_type': 'paragraph', 'position': '@', 'quire': 'A', 'section': 'text_only', 'currier_language': 'A', 'hand': '1', 'illustration_type': 'T', 'char_count': 43, 'word_count': 10, 'has_uncertain': False, 'has_illegible': False, 'has_alternatives': True, 'has_high_ascii': True, 'source': 'zandbergen_landini', 'source_version': 'bf5b6d4ac1e3'}

# %%
# Convert to pandas for easier exploration
pd.set_option('display.max_columns', None)

df = ds["train"].to_pandas()
print(f"Total records: {len(df)}")
df.head()
# Out:
# Total records: 4072
#   page_id  line_number  line_index line_id  \
# 0     f1r            1           1   f1r:1
# 1     f1r            2           2   f1r:2
# 2     f1r            3           3   f1r:3
# 3     f1r            4           4   f1r:4
# 4     f1r            5           5   f1r:5
#
#                                                 text  \
# 0  <%>fachys.ykal.ar.ataiin.shol.shory.[cth:oto]r...
# 1  sory.ckhar.or,y.kair.chtaiin.shar.ase.cthar.ct...
# 2  syaiir.sheky.or.ykaiin.shod.cthoary.cthes.dara...
# 3  soiin.oteey.oteo[s:r],roloty.cthiar,daiin.okai...
# 4                 sair,y.chear.cthaiin.cphar.cfhaiin
#
#                                           text_clean  line_type position  \
# 0  fachys.ykal.ar.ataiin.shol.shory.cthres.y.kor....  paragraph        @
# 1  sory.ckhar.or,y.kair.chtaiin.shar.ase.cthar.ct...  paragraph        +
# 2  syaiir.sheky.or.ykaiin.shod.cthoary.cthes.dara...  paragraph        +
# 3  soiin.oteey.oteos,roloty.cthiar,daiin.okaiin.o...  paragraph        +
# 4                 sair,y.chear.cthaiin.cphar.cfhaiin  paragraph        +
#
#   quire    section currier_language hand illustration_type  char_count  \
# 0     A  text_only                A    1                 T          43
# 1     A  text_only                A    1                 T          43
# 2     A  text_only                A    1                 T          44
# 3     A  text_only                A    1                 T          44
# 4     A  text_only                A    1                 T          29
#
#    word_count  has_uncertain  has_illegible  has_alternatives  has_high_ascii  \
# 0          10          False          False              True            True
# 1          11          False          False             False           False
# 2           9          False          False             False           False
# 3           9          False          False              True           False
# 4           6          False          False             False           False
#
#                source source_version
# 0  zandbergen_landini   bf5b6d4ac1e3
# 1  zandbergen_landini   bf5b6d4ac1e3
# 2  zandbergen_landini   bf5b6d4ac1e3
# 3  zandbergen_landini   bf5b6d4ac1e3
# 4  zandbergen_landini   bf5b6d4ac1e3

# %% [markdown]
# ## Basic Statistics

# %%
# Count by Currier language
print("Lines by Currier Language:")
print(df["currier_language"].value_counts())
# Out:
# Lines by Currier Language:
# currier_language
# B    2437
# A    1562
# Name: count, dtype: int64

# %%
# Count by section
print("\nLines by Section:")
print(df["section"].value_counts())
# Out:
# Lines by Section:
# section
# herbal            1612
# stars             1159
# biological         722
# text_only          277
# pharmaceutical     223
# cosmological        48
# astronomical        31
# Name: count, dtype: int64

# %%
# Count by line type
print("\nLines by Type:")
print(df["line_type"].value_counts())
# Out:
# Lines by Type:
# line_type
# paragraph    3957
# label         115
# Name: count, dtype: int64

# %% [markdown]
# ## Filter Examples

# %%
# Get all herbal section lines
herbal = df[df["section"] == "herbal"]
print(f"Herbal section: {len(herbal)} lines")
# Out:
# Herbal section: 1612 lines

# %%
# Get lines with uncertain readings
uncertain = df[df["has_uncertain"]]
print(f"Lines with uncertain readings: {len(uncertain)}")
# Out:
# Lines with uncertain readings: 84

# %%
# Compare Language A vs Language B
lang_a = df[df["currier_language"] == "A"]
lang_b = df[df["currier_language"] == "B"]

print(f"Language A: {len(lang_a)} lines, avg words: {lang_a['word_count'].mean():.1f}")
print(f"Language B: {len(lang_b)} lines, avg words: {lang_b['word_count'].mean():.1f}")
# Out:
# Language A: 1562 lines, avg words: 6.9
# Language B: 2437 lines, avg words: 9.2

# %% [markdown]
# ## Character Frequency Analysis

# %%
from collections import Counter

# Count all characters in clean text
all_text = "".join(df["text_clean"].fillna(""))
# Remove separators
all_text = all_text.replace(".", "").replace(",", "")

char_counts = Counter(all_text)
print("Top 15 characters:")
for char, count in char_counts.most_common(15):
    pct = count / len(all_text) * 100
    print(f"  {char}: {count:,} ({pct:.1f}%)")
# Out:
# Top 15 characters:
#   o: 22,022 (12.9%)
#   e: 17,820 (10.4%)
#   h: 16,120 (9.4%)
#   y: 15,817 (9.3%)
#   a: 12,627 (7.4%)
#   c: 11,904 (7.0%)
#   d: 11,673 (6.8%)
#   i: 10,745 (6.3%)
#   k: 9,850 (5.8%)
#   l: 9,380 (5.5%)
#   r: 6,435 (3.8%)
#   s: 6,433 (3.8%)
#   t: 5,808 (3.4%)
#   n: 5,697 (3.3%)
#   q: 5,286 (3.1%)

# %% [markdown]
# ## Local Loading (from Parquet file)
#
# If you have the local parquet file from the repository:

# %%
# Alternative: Load from local parquet
# from datasets import load_dataset
# ds_local = load_dataset("parquet", data_files="output/eva_lines.parquet")
# print(ds_local)
